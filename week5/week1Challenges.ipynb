# %% [markdown]
# # My first Python Notbook
# ### Week 1 programming Challenges

# %%
name = input("What is your name")
while len(name) ==0:
    name = input("What is your name")
while True:
    try:
        length = float(input('Enter the length:'))
        width = float(input('Enter the length:'))
        height = float(input('Enter the length:'))
        break
    except ValueError:
        print('Dont be silly we need numbers only')


print(f'The volume of the cube is {length*width*height} cubic units')
# Out:
# Dont be silly we need numbers only
# The volume of the cube is 137.5 cubic units

# %%
greet("Amelia")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 greet("Amelia")
#
# NameError: name 'greet' is not defined

# %%
def FTempConverter():
    '''Tem converter'''
    temp = float(input(" Enter Celcius temp: "))
    f = (temp*9)/5+32
    print(f"{temp} C is {f} F")
FTempConverter()
# Out:
# 56.0 C is 132.8 F

# %%
temp = float input("enter temprature Celsuis")
a = temp
b = 9/5 + 32
sum = a*b
print(f"temp fahrenheit is {sum}")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 4
#       2 a = temp
#       3 b = 9/5 + 32
# ----> 4 sum = a*b
#       5 print(f"temp fahrenheit is {sum}")
#
# TypeError: can't multiply sequence by non-int of type 'float'
