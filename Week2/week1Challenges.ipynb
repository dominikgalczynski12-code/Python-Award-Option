# %% [markdown]
# # My first Python Notbook
# ### Week 1 programming Challenges

# %%
number = int(input("Put in your number: "))
if number > 0:
    print("Your number is positive")
elif number < 0:
    print("Your number is negative")
else:
    print("Your number is 0")
# Out:
# Your number is 0

# %%
number = int(input("Guess number between 1-10: "))
number = > 0 and < 11
# Out:
# iteration0
# iteration1
# iteration2
# iteration3
# iteration4
# iteration5
# iteration6
# iteration7
# iteration8
# iteration9
# iteration10

# %%
def timeTable():
    "Prints the tables for given number"
    num + int(input('Enter a number to print:'))
    
    #num *1 = num*1
    for i in range(12):
        print(f'{num} times {i+1} = {num* (i+1)}')
# Out:
# 56.0 C is 132.8 F

# %%
def fizzBuzz():
    "Prints fizz buzz"
for i in range(51):
        if i%3 == 0:
            print("fizz")
    elif i%5 ==0:
        print("Buzz")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 4
#       2 a = temp
#       3 b = 9/5 + 32
# ----> 4 sum = a*b
#       5 print(f"temp fahrenheit is {sum}")
#
# TypeError: can't multiply sequence by non-int of type 'float'
